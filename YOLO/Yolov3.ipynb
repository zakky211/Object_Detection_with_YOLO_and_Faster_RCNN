# %%
# %cd /content/drive/MyDrive/Indonesia_AI/Project2/YOLO
# Out:
# [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/Indonesia_AI/Project2/YOLO'
# c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#!unrar x '/content/drive/MyDrive/Indonesia_AI/Project2/YOLO/images.rar' -d '/content/drive/MyDrive/Indonesia_AI/Project2/YOLO/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !apt-get update
# !apt-get install build-essential
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd './darknet'
# Out:
# [WinError 3] The system cannot find the path specified: "'./darknet'"
# c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO

# %%
# Configure
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#!wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !make
# Out:
# 'make' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd '../'
# Out:
# [WinError 3] The system cannot find the path specified: "'../'"
# c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python 'creating-files-data-and-name.py'
# Out:
# python: can't open file 'c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO\'creating-files-data-and-name.py'': [Errno 2] No such file or directory

# %%
# !python 'creating-train-and-test-txt-files.py'
# Out:
# python: can't open file 'c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO\'creating-train-and-test-txt-files.py'': [Errno 2] No such file or directory

# %%
# %cd './custom_weight'
# Out:
# [WinError 3] The system cannot find the path specified: "'./custom_weight'"
# c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd '../'
# Out:
# [WinError 3] The system cannot find the path specified: "'../'"
# c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO

# %%
# %cd './darknet'
# Out:
# [WinError 3] The system cannot find the path specified: "'./darknet'"
# c:\Users\ISO TEAM\BOOTCAMP CV\PROYEK\OBJECT DETECTION\REFERENCE\HADI\Project2-20230803T121526Z-001\Project2\YOLO

# %%
# !./darknet detector  \
train /content/drive/MyDrive/Indonesia_AI/Project2/YOLO/images/labelled_data.data \
/content/drive/MyDrive/Indonesia_AI/Project2/YOLO/darknet/cfg/yolov3_custom.cfg \
/content/drive/MyDrive/Indonesia_AI/Project2/YOLO/custom_weight/darknet53.conv.74 -dont_show
# Out:
# '.' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#continue training
# !./darknet detector  \
train /content/drive/MyDrive/Indonesia_AI/Project2/YOLO/images/labelled_data.data \
/content/drive/MyDrive/Indonesia_AI/Project2/YOLO/darknet/cfg/yolov3_custom.cfg \
/content/drive/MyDrive/Indonesia_AI/Project2/YOLO/custom_weight/darknet53.conv.74 -clear
# Out:
# '.' is not recognized as an internal or external command,
# operable program or batch file.
